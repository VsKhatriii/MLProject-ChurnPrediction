# %% [markdown]
# EDA Analysis

# %%
# importing the required libraries
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.ticker as mtick  
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Loading the data file

# %%
path = ('WA_Fn-UseC_-Telco-Customer-Churn.csv')
telco_base_data = pd.read_csv(path)

# %%
# top 5 records of data

telco_base_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# #### Checking all the columns and shape of the data

# %%
telco_base_data.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
telco_base_data.shape
# Out:
# (7043, 21)

# %%
# Checking the data types of all the columns

telco_base_data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# Checking the descriptive statistics of numerical variables

telco_base_data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [raw]
# SeniorCitizen is actually a categorical hence the 25%-50%-75% distribution is not propoer
#
# 75% customers have tenure less than 55 months
#
# Average Monthly charges are USD 64.76 whereas 25% customers pay more than USD 89.85 per month

# %%
telco_base_data['Churn'].value_counts().plot(kind='barh', figsize=(10, 6))
plt.xlabel('Counts')
plt.ylabel('Target Variable')
plt.title("Count of TARGET Variable per category")
# Out:
# Text(0.5, 1.0, 'Count of TARGET Variable per category')

# %%
telco_base_data['Churn'].value_counts()/len(telco_base_data['Churn'])*100
# Out:
# No     73.463013
# Yes    26.536987
# Name: Churn, dtype: float64

# %% [markdown]
# - Data is highly imbalanced, ratio = 73:27
# - So we analyse the data with other features while taking the target values separately to get some insights.

# %%
# As we have to many columns, we are using the verbase = True mode

telco_base_data.info('varbase=True')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
missing = pd.DataFrame((telco_base_data.isnull().sum())*100/telco_base_data.shape[0]).reset_index()
plt.figure(figsize=(16,5))
sns.pointplot(x='index', y=0, data=missing) 
plt.xticks(rotation=90, fontsize=7)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %% [markdown]
# #### Missing Data - Initial Intuition
# - Here, we don't have any missing data.
#
# General Thumb Rules:
#
# - For features with less missing values- can use regression to predict the missing values or fill with the mean of the values present, depending on the feature.
# - For features with very high number of missing values- it is better to drop those columns as they give very less insight on analysis.
# - As there's no thumb rule on what criteria do we delete the columns with high number of missing values, but generally you can delete the columns, if you have more than 30-40% of missing values. But again there's a catch here, for example, Is_Car & Car_Type, People having no cars, will obviously have Car_Type as NaN (null), but that doesn't make this column useless, so decisions has to be taken wisely.

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# #### 1. Creating a copy od base data for manupulation & processing

# %%
telco_data = telco_base_data.copy()

# %% [markdown]
# #### 2. Total Charges should be numeric amount So converting it to numerical data type

# %%
telco_data['TotalCharges'] = pd.to_numeric(telco_data['TotalCharges'], errors='coerce')

# %%
telco_data.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# #### 3. As we can see there are 11 missing values in TotalCharges column. Let's check these records

# %%
telco_data[telco_data['TotalCharges'].isnull()]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
# #### 4. Missing Value Treatment

# %% [markdown]
# Since the % of these records compared to total dataset is very low ie 0.15%, it is safe to ignore them from further processing.

# %%
#Removing missing values 

telco_data.dropna(how='any', inplace=True)
telco_data
#telco_data.fillna(0)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# Get the max tenure
print(telco_data['tenure'].max()) #72
# Out:
# 72

# %%
# Group the tenure in bins of 12 months
label=[]
for i in range(1, 72, 12):
    x = f'{i} - {i+11}'
    label.append(x)

#can also use 
# label = ["{0} - {1}".format(i, i + 11) for i in range(1, 72, 12)]


telco_data['tenure_group'] = pd.cut(telco_data.tenure,bins=range(1,80,12), right=False, labels=label)

# %%
telco_data['tenure_group'].value_counts()
# Out:
# 1 - 12     2175
# 61 - 72    1407
# 13 - 24    1024
# 25 - 36     832
# 49 - 60     832
# 37 - 48     762
# Name: tenure_group, dtype: int64

# %% [markdown]
# #### 6. Removing columns not required for processing

# %%
#drop column customerID and tenure
telco_data.drop(columns=['customerID', 'tenure'], axis =1, inplace=True)
telco_data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %% [markdown]
# # Data Exploration

# %% [markdown]
# #### 1. Plot distibution of individual predictors by churn

# %% [markdown]
# # Univariate Analysis

# %%
for i, predictor in enumerate(telco_data.drop(columns=['Churn', 'TotalCharges', 'MonthlyCharges'])):
    plt.figure(i)
    sns.countplot(data=telco_data, x=predictor, hue='Churn')

# #also
# for i, predictor in telco_data.drop(columns=['Churn', 'TotalCharges', 'MonthlyCharges']).items():
#     plt.figure(i)
#     sns.countplot(data=telco_data, x=predictor, hue='Churn')

# %% [markdown]
# 2. Convert the target variable 'Churn' in a binary numeric variable i.e. Yes=1 ; No = 0

# %%
telco_data['Churn'] = np.where(telco_data.Churn == 'Yes', 1, 0)

# %%
telco_data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %% [markdown]
# 3. Convert all the categorical variables into dummy variables

# %%
telco_data_dummies = pd.get_dummies(telco_data)
telco_data_dummies.head()
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0           29.85         29.85      0              1
# 1              0           56.95       1889.50      0              0
# 2              0           53.85        108.15      1              0
# 3              0           42.30       1840.75      0              0
# 4              0           70.70        151.65      1              1
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0            0           0            1              1               0  ...
# 1            1           1            0              1               0  ...
# 2            1           1            0              1               0  ...
# 3            1           1            0              1               0  ...
# 4            0           1            0              1               0  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                        0
# ...

# %% [markdown]
# 9. Relationship between Monthly Charges and Total Charges

# %%
sns.lmplot(data=telco_data_dummies, x='MonthlyCharges', y='TotalCharges',fit_reg=False)

# %% [markdown]
# Total Charges increase as Monthly Charges increase - as expected.

# %% [markdown]
# 10. Churn by Monthly Charges and Total Charges

# %%
# KDE plot for non-churned customers (color: red)
mth = sns.kdeplot(telco_data_dummies.MonthlyCharges[telco_data_dummies["Churn"] == 0], color='red', shade=True)

# KDE plot for churned customers (color: blue)
mth = sns.kdeplot(telco_data_dummies.MonthlyCharges[telco_data_dummies["Churn"] == 1], color='blue', shade=True)

plt.title("Monthly charges by churn")
plt.xlabel("Monthly Charges")
plt.ylabel("Density")
plt.legend(["Non-Churned", "Churned"])
plt.show()
# Out:
# C:\Users\visha\AppData\Local\Temp\ipykernel_5632\3352867021.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   mth = sns.kdeplot(telco_data_dummies.MonthlyCharges[telco_data_dummies["Churn"] == 0], color='red', shade=True)
# C:\Users\visha\AppData\Local\Temp\ipykernel_5632\3352867021.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   mth = sns.kdeplot(telco_data_dummies.MonthlyCharges[telco_data_dummies["Churn"] == 1], color='blue', shade=True)

# %%
# KDE plot for non-churned customers (color: red)
mth = sns.kdeplot(telco_data_dummies.TotalCharges[telco_data_dummies["Churn"] == 0], color='red', shade=True)

# KDE plot for churned customers (color: blue)
mth = sns.kdeplot(telco_data_dummies.TotalCharges[telco_data_dummies["Churn"] == 1], color='blue', shade=True)

plt.title("Total Charges by churn")
plt.xlabel("Monthly Charges")
plt.ylabel("Density")
plt.legend(["Non-Churned", "Churned"])
plt.show()
# Out:
# C:\Users\visha\AppData\Local\Temp\ipykernel_5632\3436883889.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   mth = sns.kdeplot(telco_data_dummies.TotalCharges[telco_data_dummies["Churn"] == 0], color='red', shade=True)
# C:\Users\visha\AppData\Local\Temp\ipykernel_5632\3436883889.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   mth = sns.kdeplot(telco_data_dummies.TotalCharges[telco_data_dummies["Churn"] == 1], color='blue', shade=True)

# %% [markdown]
# Surprising insight as higher Churn at lower Total Charges
#
# However if we combine the insights of 3 parameters i.e. Tenure, Monthly Charges & Total Charges then the picture is bit clear :- Higher Monthly Charge at lower tenure results into lower Total Charge. Hence, all these 3 factors viz Higher Monthly Charge, Lower tenure and Lower Total Charge are linkd to High Churn.

# %% [markdown]
# 11. Build a corelation of all predictors with 'Churn'

# %%
plt.figure(figsize=(20,10))
telco_data_dummies.corr()['Churn'].sort_values(ascending = False).plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20, 10))
sns.barplot(x=telco_data_dummies.corr()['Churn'].sort_values(ascending=False).index, y=telco_data_dummies.corr()['Churn'].sort_values(ascending=False).values)
plt.xticks(rotation=90)
plt.title("Correlation of Features with Churn")
plt.show()

# %% [markdown]
# Derived Insight:
#
# HIGH Churn seen in case of Month to month contracts, No online security, No Tech support, First year of subscription and Fibre Optics Internet
#
# LOW Churn is seens in case of Long term contracts, Subscriptions without internet service and The customers engaged for 5+ years
#
# Factors like Gender, Availability of PhoneService and # of multiple lines have alomost NO impact on Churn
#
# This is also evident from the Heatmap below

# %%
plt.figure(figsize=(12,12))
sns.heatmap(telco_data_dummies.corr(),cmap="Paired")
# Out:
# <Axes: >

# %% [markdown]
# Bivariate Analysis

# %%
new_df1_target0=telco_data[telco_data["Churn"]==0]
new_df1_target1=telco_data[telco_data["Churn"]==1]

# %%
def uniplot(df,col,title,hue =None):
    
    plt.xticks(rotation=90)    
    plt.title(title)
    ax = sns.countplot(data = df,order=df[col].value_counts().index, x= col,hue = hue)         
    plt.show()

# %%
uniplot(new_df1_target1,col='Partner',title='Distribution of Gender for Churned Customers',hue='gender')

# %%
uniplot(new_df1_target1,col='PaymentMethod',title='Distribution of PaymentMethod for Churned Customers',hue='gender')

# %%
uniplot(new_df1_target1,col='Contract',title='Distribution of Contract for Churned Customers',hue='gender')

# %%
uniplot(new_df1_target1,col='TechSupport',title='Distribution of TechSupport for Churned Customers',hue='gender')

# %%
uniplot(new_df1_target1,col='SeniorCitizen',title='Distribution of SeniorCitizen for Churned Customers',hue='gender')

# %% [markdown]
# CONCLUSION

# %% [markdown]
# These are some of the quick insights from this exercise:
#
# Electronic check medium are the highest churners
# Contract Type - Monthly customers are more likely to churn because of no contract terms, as they are free to go customers.
# No Online security, No Tech Support category are high churners
# Non senior Citizens are high churners

# %%
telco_data_dummies.to_csv('tel_churn.csv')
